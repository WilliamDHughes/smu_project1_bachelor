# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import zipfile

# %%
bachelor_contest = "C:/Users/Will/Downloads/archive.zip"
other_bachelor = "C:/Users/Will/Downloads/bachelor contestants for data.world.xlsx"
kaggle2 = "C:/Users/Will/Downloads/archive (1).zip"

# %%
bachelor_zf = zipfile.ZipFile(bachelor_contest)
bachelor_zf2 = zipfile.ZipFile(other_bachelor)

# %%
# df1 = pd.read_csv(bachelor_kaggle2.open('contestants.csv'))
# df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df1 = pd.read_csv(bachelor_kaggle2.open('contestants.csv'))
#       2 df1.head()
#
# NameError: name 'bachelor_kaggle2' is not defined

# %%
data_xls = pd.read_excel(other_bachelor, 'Contestants', index_col=None)
data_xls.to_csv('csvfile.csv', encoding='utf-8')
followers_df = data_xls
followers_df.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country                 Occupation Outcome  Elimination_Week  \
# 0    Illinois     USA          Marketing Manager  Week 3                 3
# 1  California     USA  Cadaver Tissue Saleswoman  Week 1                 1
# 2     Florida     USA          Massage Therapist  Week 1                 1
# 3       Texas     USA       Grade School Teacher  Week 1                 1
# 4  New Jersey     USA     Former NFL Cheerleader  Week 4                 4
#
#    Place Note  Was_Bachelorette
# 0   14.0  NaN                 0
# 1   24.0  NaN                 0
# 2   19.0  NaN                 0
# 3   19.0  NaN                 0
# 4   12.0  NaN                 0

# %%
df1 = pd.read_csv(bachelor_zf. open('bachelor-contestants.csv'))
df1.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season
# 0       Chanute, Kansas     NaN       NaN       1
# 1        Miami, Florida     NaN       6.0       1
# 2         Dallas, Texas     NaN       5.0       1
# 3        Tempe, Arizona     NaN       4.0       1
# 4  Terra Haute, Indiana     NaN       3.0       1

# %%
df1 = df1.merge(followers_df, how='left')
df1.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  Height  ElimWeek  Season Last Name  Followers(k)  \
# 0       Chanute, Kansas     NaN       NaN       1       NaN           NaN
# 1        Miami, Florida     NaN       6.0       1       NaN           NaN
# 2         Dallas, Texas     NaN       5.0       1       NaN           NaN
# 3        Tempe, Arizona     NaN       4.0       1       NaN           NaN
# 4  Terra Haute, Indiana     NaN       3.0       1       NaN           NaN
#
#     City    State Country Outcome  Elimination_Week  Place Note  \
# 0    NaN      NaN     NaN     NaN               NaN    NaN  NaN
# 1    NaN      NaN     NaN     NaN               NaN    NaN  NaN
# 2    NaN      NaN     NaN     NaN               NaN    NaN  NaN
# 3  Tempe  Arizona     USA  Week 4               4.0    NaN  NaN
# 4    NaN      NaN     NaN     NaN               NaN    NaN  NaN
#
#    Was_Bachelorette
# 0               NaN
# 1               NaN
# 2               NaN
# 3               0.0
# 4               NaN

# %%
df2 = df1.drop(['Last Name', 'Height', 'City', 'State', 'Country', 'Outcome', 'Elimination_Week', 'Was_Bachelorette', 'Note', 'Place'], axis=1)
df2.head()
# Out:
#              Name   Age                       Occupation  \
# 0    Amanda Marsh  23.0                    Event Planner
# 1     Trista Rehn  29.0                Miami Heat Dancer
# 2  Shannon Oliver  24.0  Financial Management Consultant
# 3             Kim  24.0                            Nanny
# 4    Cathy Grimes  22.0                 Graduate Student
#
#                Hometown  ElimWeek  Season  Followers(k)
# 0       Chanute, Kansas       NaN       1           NaN
# 1        Miami, Florida       6.0       1           NaN
# 2         Dallas, Texas       5.0       1           NaN
# 3        Tempe, Arizona       4.0       1           NaN
# 4  Terra Haute, Indiana       3.0       1           NaN

# %%
# df2 = pd.read_csv(bachelor_zf. open('bachelorette-contestants.csv'))
# df3 = pd.read_csv(bachelor_zf. open('bachelorettes.csv'))
# df4 = pd.read_csv(bachelor_zf. open('bachelors.csv'))

# %%
df2.sort_values(by='Age')
# Out:
#                    Name   Age                           Occupation  \
# 71        Jessica Kyron  21.0                              Student
# 344   Mackenzie Deonigi  21.0                     Dental Assistant
# 45               Fatima  22.0                      College Student
# 18               Jackie  22.0                          Bar Manager
# 315  Cassandra Ferguson  22.0                    Former NBA Dancer
# ..                  ...   ...                                  ...
# 279       Holly Johnson  34.0  Pharmaceutical sales representative
# 281        Shira Astrof  35.0                              Actress
# 151         Susan Stein  35.0                      Project analyst
# 198        Renee Simlak  36.0                     Jewelry Designer
# 96       Cosetta Blanca   NaN                               Dancer
#
#                               Hometown  ElimWeek  Season  Followers(k)
# 71                    Cincinnati, Ohio       1.0       5           NaN
# 344           Maple Valley, Washington       5.0      19           NaN
# 45              Long Beach, California       1.0       2           NaN
# 18            Pittsburgh, Pennsylvania       1.0       1           NaN
# 315  Shelby Charter Township, Michigan       6.0      18           NaN
# ..                                 ...       ...     ...           ...
# 279             Salyersville, Kentucky       1.0      16           NaN
# 281          Massapequa Park, New York       1.0      16           NaN
# 151              St. Charles, Illinois       1.0      11           NaN
# 198               Southfield, Michigan       1.0      13           NaN
# 96                               Italy       1.0       9           NaN
#
# [423 rows x 7 columns]

# %%
#21-24, 25-29, 30-33, 34-37

# %%
bins = [0, 24, 29, 34, 39]
age_groups = ['Early 20s', 'Late 20s', 'Early 30s', 'Late 30s']

df2['Age_groups'] = pd.cut(df2['Age'], bins, labels=age_groups, include_lowest=True)
df2
# Out:
#                Name   Age                       Occupation  \
# 0      Amanda Marsh  23.0                    Event Planner
# 1       Trista Rehn  29.0                Miami Heat Dancer
# 2    Shannon Oliver  24.0  Financial Management Consultant
# 3               Kim  24.0                            Nanny
# 4      Cathy Grimes  22.0                 Graduate Student
# ..              ...   ...                              ...
# 418           Sarah  26.0             Grade School Teacher
# 419        Susannah  26.0                  Account Manager
# 420          Taylor  23.0          Mental Health Counselor
# 421         Vanessa  29.0        Special Education Teacher
# 422         Whitney  25.0               Pilates Instructor
#
#                      Hometown  ElimWeek  Season  Followers(k) Age_groups
# 0             Chanute, Kansas       NaN       1           NaN  Early 20s
# 1              Miami, Florida       6.0       1           NaN   Late 20s
# 2               Dallas, Texas       5.0       1           NaN  Early 20s
# 3              Tempe, Arizona       4.0       1           NaN  Early 20s
# 4        Terra Haute, Indiana       3.0       1           NaN  Early 20s
# ..                        ...       ...     ...           ...        ...
# 418         Newport Beach, CA       4.0      21       217.000   Late 20s
# 419             San Diego, CA       1.0      21         1.097   Late 20s
# 420               Seattle, WA       5.0      21        47.300  Early 20s
# 421  Montreal, Quebec, Canada       NaN      21       941.000   Late 20s
# 422            Chanhassen, MN       6.0      21        72.800   Late 20s
#
# [423 rows x 8 columns]

# %%
counts = df2['ElimWeek'].value_counts()

# %%
plt.pie(counts)
plt.show()

# %%
# bins = [0, 24, 29, 34, 39]
# age_groups = ['Early 20s', 'Late 20s', 'Early 30s', 'Late 30s']

# df2['Age_groups'] = pd.cut(df2['Age'], bins, labels=age_groups, include_lowest=True)
# df2

# %%
# # all_roses = pd.merge(df1, df2, how='outer', on='Name')
# all_roses = pd.concat([df1, df2])
# all_roses.tail()

# %%
# all_roses['Age_groups'] = pd.cut(all_roses['Age'], bins, labels=age_groups, include_lowest=True)
# all_roses.tail()

# %%
# df2 = df2.sort_values(['ElimWeek'])
# df2.tail(5)
