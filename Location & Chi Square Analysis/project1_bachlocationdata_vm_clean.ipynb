# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
from scipy.stats import linregress
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
import json
import requests
import time
from api_keys_vm_copy import API_KEY

# %%
#import original cleaned & merged file
bachelorgroupdata_path = "data-bach/csvfile copy.csv"
bachdf1= pd.read_csv(bachelorgroupdata_path)
bachdf1.head()
# Out:
#    Unnamed: 0  Season     Name   Last Name  Followers(k)   Age  \
# 0           0      18  Christy      Hansen         0.148  24.0
# 1           1      19   Reegan    Cornwell         0.566  28.0
# 2           2      18      Amy     Jokinen         0.640  31.0
# 3           3      18   Ashley         Poe         0.673  25.0
# 4           4      19    Nikki  Delventhal         0.807  26.0
#
#                 City       State Country                 Occupation Outcome  \
# 0             Aurora    Illinois     USA          Marketing Manager  Week 3
# 1    Manhattan Beach  California     USA  Cadaver Tissue Saleswoman  Week 1
# 2             Apopka     Florida     USA          Massage Therapist  Week 1
# 3            Roanoke       Texas     USA       Grade School Teacher  Week 1
# 4  Hasbrouck Heights  New Jersey     USA     Former NFL Cheerleader  Week 4
#
#    Elimination_Week  Place Note  Was_Bachelorette
# 0                 3   14.0  NaN                 0
# 1                 1   24.0  NaN                 0
# 2                 1   19.0  NaN                 0
# 3                 1   19.0  NaN                 0
# 4                 4   12.0  NaN                 0

# %%
bachdf1.drop("Unnamed: 0", axis=1, inplace=True) # drop unneeded index column
bachdf1.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country                 Occupation Outcome  Elimination_Week  \
# 0    Illinois     USA          Marketing Manager  Week 3                 3
# 1  California     USA  Cadaver Tissue Saleswoman  Week 1                 1
# 2     Florida     USA          Massage Therapist  Week 1                 1
# 3       Texas     USA       Grade School Teacher  Week 1                 1
# 4  New Jersey     USA     Former NFL Cheerleader  Week 4                 4
#
#    Place Note  Was_Bachelorette
# 0   14.0  NaN                 0
# 1   24.0  NaN                 0
# 2   19.0  NaN                 0
# 3   19.0  NaN                 0
# 4   12.0  NaN                 0

# %%
bachdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            423 non-null    int64
#  1   Name              423 non-null    object
#  2   Last Name         380 non-null    object
#  3   Followers(k)      112 non-null    float64
#  4   Age               422 non-null    float64
#  5   City              422 non-null    object
#  6   State             419 non-null    object
#  7   Country           423 non-null    object
#  8   Occupation        423 non-null    object
#  9   Outcome           423 non-null    object
#  10  Elimination_Week  423 non-null    int64
#  11  Place             271 non-null    float64
#  12  Note              14 non-null     object
#  13  Was_Bachelorette  423 non-null    int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 46.4+ KB

# %%
#Import file with cleaned up occupations 
bachjobclean_path = "data-bach/occupation clean.csv"
bachdf = pd.read_csv(bachjobclean_path)
bachdf.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette
# 0  NaN                 0
# 1  NaN                 0
# 2  NaN                 0
# 3  NaN                 0
# 4  NaN                 0

# %%
bachdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            423 non-null    int64
#  1   Name              423 non-null    object
#  2   Last Name         380 non-null    object
#  3   Followers(k)      112 non-null    float64
#  4   Age               422 non-null    float64
#  5   City              422 non-null    object
#  6   State             419 non-null    object
#  7   Country           423 non-null    object
#  8   Occupation        423 non-null    object
#  9   Outcome           423 non-null    object
#  10  Elimination_Week  423 non-null    int64
#  11  Place             271 non-null    float64
#  12  Note              14 non-null     object
#  13  Was_Bachelorette  423 non-null    int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 46.4+ KB

# %%
# fill NA for address
# bachdf["City"] = bachdf.City.fillna("")

bachdf = bachdf.loc[pd.notnull(bachdf.City)].reset_index(drop=True) #Drop rows with null cities
bachdf["State"] = bachdf.State.fillna("")

bachdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            422 non-null    int64
#  1   Name              422 non-null    object
#  2   Last Name         379 non-null    object
#  3   Followers(k)      112 non-null    float64
#  4   Age               422 non-null    float64
#  5   City              422 non-null    object
#  6   State             422 non-null    object
#  7   Country           422 non-null    object
#  8   Occupation        422 non-null    object
#  9   Outcome           422 non-null    object
#  10  Elimination_Week  422 non-null    int64
#  11  Place             271 non-null    float64
#  12  Note              14 non-null     object
#  13  Was_Bachelorette  422 non-null    int64
# dtypes: float64(3), int64(3), object(8)
# memory usage: 46.3+ KB

# %%
bachdf["City"].value_counts()
# Out:
# Dallas          9
# Los Angeles     7
# Seattle         7
# Chicago         7
# Tampa           6
#                ..
# Tulsa           1
# Sausalito       1
# Williamstown    1
# Sunriver        1
# Charleston      1
# Name: City, Length: 317, dtype: int64

# %%
bachdf["State"].value_counts()
# Out:
# California          66
# Florida             32
# Texas               31
# Illinois            28
# New York            19
# Ohio                14
# Washington          13
# Pennsylvania        13
# Michigan            13
# New Jersey          12
# Colorado            11
# Utah                11
# Arizona             11
# North Carolina      10
# Massachusetts        9
# Tennessee            8
# Oklahoma             8
# Oregon               8
# Kansas               7
# Kentucky             7
# Virginia             7
# Alberta              6
# Georgia              6
# Connecticut          6
# Minnesota            5
# South Carolina       5
# Missouri             4
# Louisiana            4
# Nebraska             4
# Maryland             4
# Indiana              3
#                      3
# Nevada               3
# Arkansas             3
# Wisconsin            3
# Alabama              3
# British Columbia     3
# Idaho                3
# Ontario              2
# Quebec               2
# Hawaii               2
# Rhode Island         2
# D.C                  1
# Maine                1
# Pernambuco           1
# Iowa                 1
# D.C.                 1
# Mississippi          1
# Alaska               1
# West Virginia        1
# Name: State, dtype: int64

# %%
bachdf["Country"].value_counts()
# Out:
# USA        405
# Canada      13
# Brazil       2
# Italy        1
# England      1
# Name: Country, dtype: int64

# %%
#First attempt - has duplicates - needs revision
#step 1 - get the data
states = bachdf["State"].value_counts()

x = states.index
y = states.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per State", fontname = "Helvetica", fontsize=16)
plt.title("Contestants Home States", fontsize=22, fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
bachdf.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette
# 0  NaN                 0
# 1  NaN                 0
# 2  NaN                 0
# 3  NaN                 0
# 4  NaN                 0

# %%
#Make an address for each contestant
bachdf["Address"] = bachdf.City + ", " + bachdf.State + ", " + bachdf.Country
bachdf.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette                             Address
# 0  NaN                 0               Aurora, Illinois, USA
# 1  NaN                 0    Manhattan Beach, California, USA
# 2  NaN                 0                Apopka, Florida, USA
# 3  NaN                 0                 Roanoke, Texas, USA
# 4  NaN                 0  Hasbrouck Heights, New Jersey, USA

# %%
bachdf.tail()
# Out:
#      Season       Name Last Name  Followers(k)   Age         City  \
# 417      13  Stephanie     Hogan           NaN  34.0   Huntsville
# 418       2     Hayley       NaN           NaN  28.0  Lake Oswego
# 419       5   Francine     Jones           NaN  25.0      Houston
# 420       5      Jenny  Matthews           NaN  24.0       Canton
# 421      10     Nicole     Clary           NaN  26.0   Charleston
#
#               State Country Occupation Outcome  Elimination_Week  Place Note  \
# 417         Alabama     USA      Media  Week 5                 5    5.0  NaN
# 418          Oregon     USA      Sales  Week 4                 4    NaN  NaN
# 419           Texas     USA      Sales  Week 1                 1    NaN  NaN
# 420        Michigan     USA      Sales  Week 2                 2    NaN  NaN
# 421  South Carolina     USA      Sales  Week 4                 4    NaN  NaN
#
#      Was_Bachelorette                          Address
# 417                 0         Huntsville, Alabama, USA
# 418                 0         Lake Oswego, Oregon, USA
# 419                 0              Houston, Texas, USA
# 420                 0            Canton, Michigan, USA
# 421                 0  Charleston, South Carolina, USA

# %%
address = bachdf.Address[0]
address
# Out:
# 'Aurora, Illinois, USA'

# %%
#Get location data from opwnweathermap.org

url = f"http://api.openweathermap.org/geo/1.0/direct?q={address}&appid={API_KEY}"
response = requests.get(url)

data = response.json()

if (len(data) > 0):
    location = data[0]
    print(location)
# Out:
# {'name': 'Aurora', 'local_names': {'en': 'Aurora', 'ru': 'Орора'}, 'lat': 41.7571701, 'lon': -88.3147539, 'country': 'US', 'state': 'Illinois'}

# %%
# parse data
lat = location["lat"]
lon = location["lon"]
city = location["name"]
state = location.get("state") # might not exist
country = location["country"]

row = {"latitude": lat,
      "longitude": lon,
      "city": city,
      "state": state,
      "country": country}

row
# Out:
# {'latitude': 41.7571701,
#  'longitude': -88.3147539,
#  'city': 'Aurora',
#  'state': 'Illinois',
#  'country': 'US'}

# %%
#Loop to get location info for all addresses

rows = []

for address in bachdf.Address:
    print(address)
    
    # create URL
    url = f"http://api.openweathermap.org/geo/1.0/direct?q={address}&appid={API_KEY}"
    response = requests.get(url)
    
    # get data
    data = response.json()

    if (len(data) > 0):
        location = data[0]
        
        # parse data
        lat = location["lat"]
        lon = location["lon"]
        city = location["name"]
        state = location.get("state") # might not exist
        country = location["country"]
        
        # make row
        row = {"latitude": lat,
              "longitude": lon,
              "clean_city": city,
              "clean_state": state,
              "clean_country": country}
        
    else:
        row = {"latitude": np.nan,
              "longitude": np.nan,
              "clean_city": None,
              "clean_state": None,
              "clean_country": None}
    
    rows.append(row)
    time.sleep(1)
# Out:
# Aurora, Illinois, USA
# Manhattan Beach, California, USA
# Apopka, Florida, USA
# Roanoke, Texas, USA
# Hasbrouck Heights, New Jersey, USA
# Sutter, California, USA
# Provo, Utah, USA
# San Diego, California, USA
# Wantagh, New York, USA
# Wagener, South Carolina, USA
# Miami, Florida, USA
# Brownsville, Kentucky, USA
# Harlingen, Texas, USA
# Wellington, Florida, USA
# Lake Oswego, Oregon, USA
# Houston, Texas, USA
# Canton, Michigan, USA
# Charleston, South Carolina, USA

# %%
loc_df = pd.DataFrame(rows)
loc_df.head()
# Out:
#     latitude   longitude         clean_city clean_state clean_country
# 0  41.757170  -88.314754             Aurora    Illinois            US
# 1  33.891599 -118.395124    Manhattan Beach  California            US
# 2  28.677968  -81.511521             Apopka     Florida            US
# 3  33.004013  -97.225848            Roanoke       Texas            US
# 4  40.857929  -74.081669  Hasbrouck Heights  New Jersey            US

# %%
loc_df.tail()
# Out:
#       latitude   longitude   clean_city     clean_state clean_country
# 417  34.729847  -86.585901   Huntsville         Alabama            US
# 418  45.420675 -122.670649  Lake Oswego          Oregon            US
# 419  29.758938  -95.367697      Houston           Texas            US
# 420  42.307655  -83.486896       Canton        Michigan            US
# 421  32.787601  -79.940273   Charleston  South Carolina            US

# %%
#Merge new location data
test = bachdf

full_df = pd.merge(test, loc_df, left_index=True, right_index=True)
full_df.head(10)
# Out:
#    Season      Name   Last Name  Followers(k)   Age               City  \
# 0      18   Christy      Hansen         0.148  24.0             Aurora
# 1      19    Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18       Amy     Jokinen         0.640  31.0             Apopka
# 3      18    Ashley         Poe         0.673  25.0            Roanoke
# 4      19     Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
# 5      18   Valerie      Eredia         1.042  26.0             Sutter
# 6      19  Michelle       Davis         1.049  25.0              Provo
# 7      21  Susannah       Milan         1.097  26.0          San Diego
# 8      19  Kimberly    Sherbach         1.126  28.0            Wantagh
# 9      18    Maggie       Gantt         1.141  25.0            Wagener
#
#             State Country            Occupation Outcome  Elimination_Week  \
# 0        Illinois     USA                 Media  Week 3                 3
# 1      California     USA                 Sales  Week 1                 1
# 2         Florida     USA  Health Related Field  Week 1                 1
# 3           Texas     USA             Education  Week 1                 1
# 4      New Jersey     USA            Unemployed  Week 4                 4
# 5      California     USA               Fitness  Week 1                 1
# 6            Utah     USA      Service Industry  Week 1                 1
# 7      California     USA                 Sales  Week 1                 1
# 8        New York     USA               Fitness  Week 2                 2
# 9  South Carolina     USA               Finance  Week 1                 1
#
#    Place Note  Was_Bachelorette                             Address  \
# 0   14.0  NaN                 0               Aurora, Illinois, USA
# 1   24.0  NaN                 0    Manhattan Beach, California, USA
# 2   19.0  NaN                 0                Apopka, Florida, USA
# 3   19.0  NaN                 0                 Roanoke, Texas, USA
# 4   12.0  NaN                 0  Hasbrouck Heights, New Jersey, USA
# 5   19.0  NaN                 0             Sutter, California, USA
# 6   24.0  NaN                 0                    Provo, Utah, USA
# 7   23.0  NaN                 0          San Diego, California, USA
# 8   19.0  NaN                 0              Wantagh, New York, USA
# 9   19.0  NaN                 0        Wagener, South Carolina, USA
#
#     latitude   longitude         clean_city     clean_state clean_country
# 0  41.757170  -88.314754             Aurora        Illinois            US
# 1  33.891599 -118.395124    Manhattan Beach      California            US
# 2  28.677968  -81.511521             Apopka         Florida            US
# 3  33.004013  -97.225848            Roanoke           Texas            US
# 4  40.857929  -74.081669  Hasbrouck Heights      New Jersey            US
# 5  39.159892 -121.752748             Sutter      California            US
# 6  40.233729 -111.658709              Provo            Utah            US
# 7  32.717420 -117.162773          San Diego      California            US
# 8  40.683712  -73.510126            Wantagh        New York            US
# 9  33.652371  -81.361214            Wagener  South Carolina            US

# %%
full_df.clean_state.value_counts()
# Out:
# California              66
# Florida                 32
# Texas                   31
# Illinois                28
# New York                18
# Ohio                    14
# Washington              13
# New Jersey              12
# Pennsylvania            12
# Michigan                12
# Colorado                11
# Utah                    11
# Arizona                 11
# North Carolina          10
# Massachusetts            9
# Tennessee                8
# Oklahoma                 8
# Oregon                   8
# Kansas                   7
# Kentucky                 7
# Virginia                 7
# Alberta                  6
# Georgia                  6
# Connecticut              6
# Minnesota                5
# South Carolina           5
# Missouri                 4
# Louisiana                4
# Nebraska                 4
# Maryland                 4
# Alabama                  3
# Wisconsin                3
# Nevada                   3
# Idaho                    3
# Arkansas                 3
# British Columbia         3
# Rhode Island             2
# District of Columbia     2
# Indiana                  2
# Hawaii                   2
# Ontario                  2
# Iowa                     1
# Quebec                   1
# Alaska                   1
# Mississippi              1
# Veneto                   1
# Rio Grande do Sul        1
# England                  1
# Pernambuco               1
# Maine                    1
# West Virginia            1
# Name: clean_state, dtype: int64

# %%
full_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 422 entries, 0 to 421
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            422 non-null    int64
#  1   Name              422 non-null    object
#  2   Last Name         379 non-null    object
#  3   Followers(k)      112 non-null    float64
#  4   Age               422 non-null    float64
#  5   City              422 non-null    object
#  6   State             422 non-null    object
#  7   Country           422 non-null    object
#  8   Occupation        422 non-null    object
#  9   Outcome           422 non-null    object
#  10  Elimination_Week  422 non-null    int64
#  11  Place             271 non-null    float64
#  12  Note              14 non-null     object
#  13  Was_Bachelorette  422 non-null    int64
#  14  Address           422 non-null    object
#  15  latitude          417 non-null    float64
#  16  longitude         417 non-null    float64
#  17  clean_city        417 non-null    object
#  18  clean_state       417 non-null    object
#  19  clean_country     417 non-null    object
# dtypes: float64(5), int64(3), object(12)
# memory usage: 66.1+ KB

# %%
#BAR CHART of Contestants by State for all Seasons in Data Set
# step 1 - get the data
states = full_df.clean_state.value_counts()

x = states.index
y = states.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per State", fontname = "Helvetica", fontsize=16)
plt.title("Home States of Contestants", fontsize=24, fontweight="bold", fontname = "Helvetica")
plt.xticks(fontsize=12, rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
#California, Florida, Texas, Illinois, & New York are the top 5 States that contestants are from on The Bachelor

# %%
#Save location data to csv file
full_df.to_csv("location_data.csv", index=False)

# %%
#Use location data to make other visualizations in bach_map_data file
