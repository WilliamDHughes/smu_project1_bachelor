# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data_path = "../../../../smu/occupation_clean.csv"
df= pd.read_csv(data_path)
df
# Out:
#      Season       Name   Last Name  Followers(k)   Age               City  \
# 0        18    Christy      Hansen         0.148  24.0             Aurora
# 1        19     Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2        18        Amy     Jokinen         0.640  31.0             Apopka
# 3        18     Ashley         Poe         0.673  25.0            Roanoke
# 4        19      Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
# ..      ...        ...         ...           ...   ...                ...
# 418      13  Stephanie       Hogan           NaN  34.0         Huntsville
# 419       2     Hayley         NaN           NaN  28.0        Lake Oswego
# 420       5   Francine       Jones           NaN  25.0            Houston
# 421       5      Jenny    Matthews           NaN  24.0             Canton
# 422      10     Nicole       Clary           NaN  26.0         Charleston
#
#               State Country            Occupation Outcome  Elimination_Week  \
# ...

# %%
df.columns
# Out:
# Index(['Season', 'Name', 'Last Name', 'Followers(k)', 'Age', 'City', 'State',
#        'Country', 'Occupation', 'Outcome', 'Elimination_Week', 'Place', 'Note',
#        'Was_Bachelorette'],
#       dtype='object')

# %%
#union_data = settlement_data["UNION"].value_counts()

# %%
occupation_data = df["Occupation"].value_counts()

# %%
figure1 = occupation_data.plot(kind="bar", facecolor="red", figsize=(8,6),
                                title="Occupations of Bachelor Contestants",
                                xlabel="Occupations",
                                ylabel="Number of Contestants")


xticklabels = occupation_data.index
figure1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)


plt.show()

# %%
df["Season Bin"]=None
df.loc[df.Season <= 7, "Season Bin"] = "1-7"
df.loc[(df.Season > 7) & (df.Season <= 14), "Season Bin"] = "8-14"
df.loc[df.Season >14, "Season Bin"] = "15-21"
df.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette Season Bin
# 0  NaN                 0      15-21
# ...

# %%
df["Season Bin"].value_counts()
# Out:
# 15-21    196
# 8-14     152
# 1-7       75
# Name: Season Bin, dtype: int64

# %%
Occupation = df.loc[df["Season Bin"] == "1-7"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations in Seasons 1-7", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Season Bin"] == "8-14"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations in Seasons 8-14", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Season Bin"] == "15-21"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations in Seasons 15-21", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
df["Age Bin"]=None
df.loc[(df.Age >= 20) & (df.Age <= 25), "Age Bin"] = "20-25"
df.loc[(df.Age > 25) & (df.Age <= 29), "Age Bin"] = "26-29"
df.loc[(df.Age > 29) & (df.Age <= 35), "Age Bin"] = "30-35"
df.loc[(df.Age > 35) & (df.Age <= 39), "Age Bin"] = "36-39"
df.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette Season Bin Age Bin
# ...

# %%
Occupation = df.loc[df["Age Bin"] == "20-25"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Ages 20-25", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Age Bin"] == "26-29"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Ages 26-29", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Age Bin"] == "30-35"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Ages 30-35", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Age Bin"] == "36-39"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Ages 36-39", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
df["Age Bin"].value_counts()
# Out:
# 20-25    191
# 26-29    173
# 30-35     57
# 36-39      1
# Name: Age Bin, dtype: int64

# %%
df["Elimination Bin"]=None
df.loc[(df.Elimination_Week >= 1) & (df.Elimination_Week <= 4), "Elimination Bin"] = "1-4"
df.loc[(df.Elimination_Week >= 5) & (df.Elimination_Week <= 7), "Elimination Bin"] = "5-7"
df.loc[(df.Elimination_Week >= 8) & (df.Elimination_Week <= 10), "Elimination Bin"] = "8-10"

df.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette Season Bin Age Bin Elimination Bin
# ...

# %%
Occupation = df.loc[df["Elimination Bin"] == "1-4"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Eliminated Week 1-4", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Elimination Bin"] == "5-7"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Eliminated Week 5-7", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
Occupation = df.loc[df["Elimination Bin"] == "8-10"].Occupation.value_counts().head(5)
x = Occupation.index
y = Occupation.values

# step 2 - make/init the plot
fig = plt.figure(figsize=(10, 8))
plt.bar(x, y,  color="pink")

# step 3 - customization
plt.ylabel("# of Contestants per Occupation", fontname = "Helvetica", fontsize=16)
plt.title("Contestant Occupations Eliminated Week 8-10", fontsize=24, fontstyle="italic", fontweight="bold", fontname = "Helvetica")
plt.xticks(rotation=90)

plt.grid(axis="y", alpha=0.25)

# step 4 - show/save the plot
plt.show()

# %%
df.head()
# Out:
#    Season     Name   Last Name  Followers(k)   Age               City  \
# 0      18  Christy      Hansen         0.148  24.0             Aurora
# 1      19   Reegan    Cornwell         0.566  28.0    Manhattan Beach
# 2      18      Amy     Jokinen         0.640  31.0             Apopka
# 3      18   Ashley         Poe         0.673  25.0            Roanoke
# 4      19    Nikki  Delventhal         0.807  26.0  Hasbrouck Heights
#
#         State Country            Occupation Outcome  Elimination_Week  Place  \
# 0    Illinois     USA                 Media  Week 3                 3   14.0
# 1  California     USA                 Sales  Week 1                 1   24.0
# 2     Florida     USA  Health Related Field  Week 1                 1   19.0
# 3       Texas     USA             Education  Week 1                 1   19.0
# 4  New Jersey     USA            Unemployed  Week 4                 4   12.0
#
#   Note  Was_Bachelorette Season Bin Age Bin Elimination Bin
# ...

# %%
import seaborn as sns

# %%
sns.violinplot(data=df, x="Elimination Bin", y="Age")
plt.show()

# %%
sns.violinplot(data=df, x="Elimination Bin", y="Age", hue="Was_Bachelorette", split= True)
plt.show()

# %%
sns.violinplot(data=df, x="Age Bin", y="Place")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            423 non-null    int64
#  1   Name              423 non-null    object
#  2   Last Name         380 non-null    object
#  3   Followers(k)      112 non-null    float64
#  4   Age               422 non-null    float64
#  5   City              422 non-null    object
#  6   State             419 non-null    object
#  7   Country           423 non-null    object
#  8   Occupation        423 non-null    object
#  9   Outcome           423 non-null    object
#  10  Elimination_Week  423 non-null    int64
#  11  Place             271 non-null    float64
#  12  Note              14 non-null     object
#  13  Was_Bachelorette  423 non-null    int64
#  14  Season Bin        423 non-null    object
#  15  Age Bin           422 non-null    object
# ...

# %%
df2 = df.loc[:,["Season","Age","Occupation","Elimination_Week"]].dropna()
df2 = pd.get_dummies(df2)
df2.head()
# Out:
#    Season   Age  Elimination_Week  Occupation_Beautician  \
# 0      18  24.0                 3                      0
# 1      19  28.0                 1                      0
# 2      18  31.0                 1                      0
# 3      18  25.0                 1                      0
# 4      19  26.0                 4                      0
#
#    Occupation_Education  Occupation_Entertainment  Occupation_Entrepreneur  \
# 0                     0                         0                        0
# 1                     0                         0                        0
# 2                     0                         0                        0
# 3                     1                         0                        0
# 4                     0                         0                        0
#
#    Occupation_Fashion/Design  Occupation_Finance  Occupation_Fitness  ...  \
# 0                          0                   0                   0  ...
# ...

# %%
import seaborn as sns
from scipy import stats as st

# linear modelling
import statsmodels.api as sm
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
def checkShapeOfData(df, col):
    # make histogram plot
    plt.figure(figsize=(10,6))
    sns.histplot(data=df, x=col, kde=True)
    plt.title(f"HistPlot of {col}")
    plt.show()
    print()
    
    # boxplots
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df, y=col)
    plt.title(f"Boxplot of {col}")
    plt.show()
    print()
    
    # If the data is in a dataframe, we use pandas to give quartile calculations
    quartiles = df[col].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    
    # normaltest
    print()
    print("Normal test:")
    num = int(len(df)*0.1)

# %%
cols = df2.describe().columns[0:3]
for col in cols:
    checkShapeOfData(df2, col)
# Out:
# Values below -2.0 could be outliers.
# Values above 30.0 could be outliers.
#
# Normal test:
# Values below 18.0 could be outliers.
# Values above 34.0 could be outliers.
#
# Normal test:
# Values below -5.0 could be outliers.
# Values above 11.0 could be outliers.
#
# Normal test:

# %%
df2.corr()
# Out:
#                                    Season       Age  Elimination_Week  \
# Season                           1.000000  0.006738          0.231265
# Age                              0.006738  1.000000         -0.093642
# Elimination_Week                 0.231265 -0.093642          1.000000
# Occupation_Beautician            0.064496  0.088364          0.045757
# Occupation_Education             0.006311  0.046380         -0.003014
# Occupation_Entertainment        -0.036386  0.041104         -0.007472
# Occupation_Entrepreneur          0.044256 -0.036321          0.101680
# Occupation_Fashion/Design       -0.024000  0.012769          0.009136
# Occupation_Finance              -0.044944 -0.033200         -0.063507
# Occupation_Fitness               0.037748 -0.016340         -0.007331
# Occupation_Health Related Field  0.073866  0.060768          0.061357
# Occupation_Law Related Field    -0.051776  0.078842         -0.080537
# ...

# %%
corrs = df2.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corrs)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df2.Age, df2.Elimination_Week)

plt.show()

# %%
feature = df2.drop("Elimination_Week", axis = 1)
target = df2["Elimination_Week"]

# %%
  # STATSMODELS
X = sm.add_constant(feature)
Y = target

model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       Elimination_Week   R-squared:                       0.093
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     2.168
# Date:                Thu, 10 Nov 2022   Prob (F-statistic):            0.00323
# Time:                        20:18:15   Log-Likelihood:                -977.35
# No. Observations:                 422   AIC:                             1995.
# Df Residuals:                     402   BIC:                             2076.
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                                       coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------
# ...

# %%
reg = LinearRegression()
reg.fit(np.array(feature), np.array(target))
print(reg.coef_)
print(reg.intercept_)
print(reg.score(np.array(feature), np.array(target)))
# Out:
# [ 0.09348881 -0.10434934  0.66943061  0.16750621  0.21685023  1.4850106
#   0.32084545 -0.58733208 -0.05792963  0.51855839 -0.44893277  0.06084928
#   0.97018189 -2.30452164 -0.05014983  0.32797267 -0.48973484  0.19684848
#  -0.40833692 -0.58711608]
# 4.763063991417151
# 0.09295814103753419

# %%
plt.scatter(target, reg.predict(np.array(feature)))
plt.plot(target, target)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
rf = RandomForestRegressor()
rf.fit(np.array(feature), np.array(target))
print(rf.score(np.array(feature), np.array(target)))
# Out:
# 0.7733326644335586

# %%
plt.scatter(target, rf.predict(np.array(feature)))
plt.plot(target, target)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.show()

# %%
data = feature.iloc[0]
data
# Out:
# Season                             18.0
# Age                                24.0
# Occupation_Beautician               0.0
# Occupation_Education                0.0
# Occupation_Entertainment            0.0
# Occupation_Entrepreneur             0.0
# Occupation_Fashion/Design           0.0
# Occupation_Finance                  0.0
# Occupation_Fitness                  0.0
# Occupation_Health Related Field     0.0
# Occupation_Law Related Field        0.0
# Occupation_Media                    1.0
# Occupation_Real Estate              0.0
# Occupation_Real Estate Agent        0.0
# Occupation_Sales                    0.0
# Occupation_Service Industry         0.0
# Occupation_Student                  0.0
# Occupation_Transportation           0.0
# Occupation_Unemployed               0.0
# Occupation_Veteran                  0.0
# Name: 0, dtype: float64

# %%
data["Season"] = 21
data["Age"] = 26
data["Occupation_Media"] = 0
data["Occupation_Unemployed"] = 1

reg.predict([data])
# Out:
# /var/folders/lg/dmlh3n1j32q6sftl8gxw2wbw0000gn/T/ipykernel_26466/2638571938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Season"] = 21
# /var/folders/lg/dmlh3n1j32q6sftl8gxw2wbw0000gn/T/ipykernel_26466/2638571938.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Age"] = 26
# /var/folders/lg/dmlh3n1j32q6sftl8gxw2wbw0000gn/T/ipykernel_26466/2638571938.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df2.Elimination_Week.value_counts()
# Out:
# 1     146
# 2      62
# 3      50
# 4      42
# 5      30
# 6      29
# 7      23
# 8      18
# 10     14
# 9       8
# Name: Elimination_Week, dtype: int64

# %%
df2.groupby("Season").Elimination_Week.max()
# Out:
# Season
# 1      6
# 2      7
# 5      8
# 9      8
# 10     9
# 11     8
# 12     8
# 13     8
# 14     8
# 15    10
# 16    10
# 17    10
# 18    10
# 19    10
# 20    10
# 21    10
# Name: Elimination_Week, dtype: int64

# %%
df2.groupby(["Season","Elimination_Week"]).Age.mean()
# Out:
# Season  Elimination_Week
# 1       1                   27.70
#         2                   26.00
#         3                   25.25
#         4                   24.00
#         5                   24.00
#                             ...
# 21      6                   27.00
#         7                   27.50
#         8                   24.00
#         9                   31.00
#         10                  27.00
# Name: Age, Length: 140, dtype: float64
