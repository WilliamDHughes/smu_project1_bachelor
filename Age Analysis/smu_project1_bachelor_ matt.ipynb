# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(WordCloud)
# Out:
# <class 'wordcloud.wordcloud.WordCloud'>

# %%
Bachelor_1 = "C:/Users/matt1/Desktop/SMU BootCamp/Projects/smu_project1_bachelor/csvfile.csv"
df = pd.read_csv(Bachelor_1)
df
Bachelor_1 = "C:/Users/matt1/Desktop/SMU BootCamp/Projects/smu_project1_bachelor/Merged_bachelor_data copy.csv"
df2 = pd.read_csv(Bachelor_2,  encoding="utf-8")
df2
# Out:
#     ,Name,Age,Occupation,Hometown,ElimWeek,Season,Followers(k),count,Age_groups
# 0    0,Amanda Marsh,23.0,Event Planner,"Chanute, Ka...
# 1    1,Trista Rehn,29.0,Miami Heat Dancer,"Miami, F...
# 2    2,Shannon Oliver,24.0,Financial Management Con...
# 3    3,Kim,24.0,Nanny,"Tempe, Arizona",4.0,1,,1,Ear...
# 4    4,Cathy Grimes,22.0,Graduate Student,"Terra Ha...
# ..                                                 ...
# 418  418,Sarah,26.0,Grade School Teacher,"Newport B...
# 419  419,Susannah,26.0,Account Manager,"San Diego, ...
# 420  420,Taylor,23.0,Mental Health Counselor,"Seatt...
# 421  421,Vanessa,29.0,Special Education Teacher,"Mo...
# 422  422,Whitney,25.0,Pilates Instructor,"Chanhasse...
#
# [423 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        423 non-null    int64
#  1   Season            423 non-null    int64
#  2   Name              423 non-null    object
#  3   Last Name         380 non-null    object
#  4   Followers(k)      112 non-null    float64
#  5   Age               422 non-null    float64
#  6   City              422 non-null    object
#  7   State             419 non-null    object
#  8   Country           423 non-null    object
#  9   Occupation        423 non-null    object
#  10  Outcome           423 non-null    object
#  11  Elimination_Week  423 non-null    int64
#  12  Place             271 non-null    float64
#  13  Note              14 non-null     object
#  14  Was_Bachelorette  423 non-null    int64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 49.7+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 423 entries, 0 to 422
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    423 non-null    int64
#  1   Name          423 non-null    object
#  2   Age           422 non-null    float64
#  3   Occupation    423 non-null    object
#  4   Hometown      423 non-null    object
#  5   ElimWeek      423 non-null    object
#  6   Season        423 non-null    int64
#  7   Followers(k)  26 non-null     float64
#  8   count         423 non-null    int64
#  9   Age_groups    422 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 33.2+ KB

# %%
df.head()
# Out:
#    Unnamed: 0  Season     Name   Last Name  Followers(k)   Age  \
# 0           0      18  Christy      Hansen         0.148  24.0
# 1           1      19   Reegan    Cornwell         0.566  28.0
# 2           2      18      Amy     Jokinen         0.640  31.0
# 3           3      18   Ashley         Poe         0.673  25.0
# 4           4      19    Nikki  Delventhal         0.807  26.0
#
#                 City       State Country                 Occupation Outcome  \
# 0             Aurora    Illinois     USA          Marketing Manager  Week 3
# 1    Manhattan Beach  California     USA  Cadaver Tissue Saleswoman  Week 1
# 2             Apopka     Florida     USA          Massage Therapist  Week 1
# 3            Roanoke       Texas     USA       Grade School Teacher  Week 1
# 4  Hasbrouck Heights  New Jersey     USA     Former NFL Cheerleader  Week 4
#
#    Elimination_Week  Place Note  Was_Bachelorette
# 0                 3   14.0  NaN                 0
# 1                 1   24.0  NaN                 0
# 2                 1   19.0  NaN                 0
# 3                 1   19.0  NaN                 0
# 4                 4   12.0  NaN                 0

# %%
df2.head()
# Out:
#   ,Name,Age,Occupation,Hometown,ElimWeek,Season,Followers(k),count,Age_groups
# 0  0,Amanda Marsh,23.0,Event Planner,"Chanute, Ka...
# 1  1,Trista Rehn,29.0,Miami Heat Dancer,"Miami, F...
# 2  2,Shannon Oliver,24.0,Financial Management Con...
# 3  3,Kim,24.0,Nanny,"Tempe, Arizona",4.0,1,,1,Ear...
# 4  4,Cathy Grimes,22.0,Graduate Student,"Terra Ha...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df = df.merge(followers_df, how='left')
#       2 df.head()
#
# NameError: name 'followers_df' is not defined

# %%
df = df.merge(df_z, how='left', left_index=False)
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 df = df.merge(df_z, how='left', left_index=False)
#       2 df.info()
#
# NameError: name 'df_z' is not defined

# %%
df2 = df.drop(['Last Name', 'Show', 'Job', 'Eliminated', 'Height', 'City', 'State', 'Country', 'Outcome', 'Elimination_Week', 'Was_Bachelorette', 'Note', 'Place'], axis=1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 423 entries, 0 to 422
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          423 non-null    object
#  1   Age           422 non-null    float64
#  2   Occupation    423 non-null    object
#  3   Hometown      423 non-null    object
#  4   ElimWeek      406 non-null    float64
#  5   Season        423 non-null    int64
#  6   Followers(k)  26 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 26.4+ KB

# %%
df2['ElimWeek'] = df2['ElimWeek'].fillna('Quit')

# %%
# df2 = pd.read_csv(bachelor_zf. open('bachelorette-contestants.csv'))
# df3 = pd.read_csv(bachelor_zf. open('bachelorettes.csv'))
# df4 = pd.read_csv(bachelor_zf. open('bachelors.csv'))

# %%
df2.sort_values(by="Age")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df2.sort_values(by="Age")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:6313, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6309 elif len(by):
#    6310     # len(by) == 1
#    6312     by = by[0]
# -> 6313     k = self._get_label_or_level_values(by, axis=axis)
#    6315     # need to rewrap column in Series to apply key function
#    6316     if key is not None:
#    6317         # error: Incompatible types in assignment (expression has type
#    6318         # "Series", variable has type "ndarray")
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:1840, in NDFrame._get_label_or_level_values(self, key, axis)
#    1838     values = self.axes[axis].get_level_values(key)._values
#    1839 else:
# -> 1840     raise KeyError(key)
#    1842 # Check for duplicates
#    1843 if values.ndim > 1:
#
# KeyError: 'Age'

# %%
count = 1
df2['count'] = count

# %%
#21-24, 25-29, 30-33, 34-37

# %%
bins = [0, 24, 29, 34, 39]
age_groups = ['Early 20s', 'Late 20s', 'Early 30s', 'Late 30s']

df2['Age_groups'] = pd.cut(df2['Age'], bins, labels=age_groups, include_lowest=True)
df2
# Out:
#                Name   Age                       Occupation  \
# 0      Amanda Marsh  23.0                    Event Planner
# 1       Trista Rehn  29.0                Miami Heat Dancer
# 2    Shannon Oliver  24.0  Financial Management Consultant
# 3               Kim  24.0                            Nanny
# 4      Cathy Grimes  22.0                 Graduate Student
# ..              ...   ...                              ...
# 418           Sarah  26.0             Grade School Teacher
# 419        Susannah  26.0                  Account Manager
# 420          Taylor  23.0          Mental Health Counselor
# 421         Vanessa  29.0        Special Education Teacher
# 422         Whitney  25.0               Pilates Instructor
#
#                      Hometown ElimWeek  Season  Followers(k)  count Age_groups
# 0             Chanute, Kansas     Quit       1           NaN      1  Early 20s
# 1              Miami, Florida      6.0       1           NaN      1   Late 20s
# 2               Dallas, Texas      5.0       1           NaN      1  Early 20s
# 3              Tempe, Arizona      4.0       1           NaN      1  Early 20s
# 4        Terra Haute, Indiana      3.0       1           NaN      1  Early 20s
# ..                        ...      ...     ...           ...    ...        ...
# 418         Newport Beach, CA      4.0      21       217.000      1   Late 20s
# 419             San Diego, CA      1.0      21         1.097      1   Late 20s
# 420               Seattle, WA      5.0      21        47.300      1  Early 20s
# 421  Montreal, Quebec, Canada     Quit      21       941.000      1   Late 20s
# 422            Chanhassen, MN      6.0      21        72.800      1   Late 20s
#
# [423 rows x 9 columns]

# %%
age_means = df2.groupby(['Age_groups', 'ElimWeek'], as_index=False).sum()
age_means.head(5)
# Out:
#   Age_groups ElimWeek    Age  Season  Followers(k)  count
# 0  Early 20s      1.0  887.0     466         3.361     38
# 1  Early 20s      2.0  307.0     172        13.215     13
# 2  Early 20s      3.0  346.0     124         0.000     15
# 3  Early 20s      4.0  256.0     128         0.000     11
# 4  Early 20s      5.0  303.0     196       329.900     13

# %%
counts = df2['ElimWeek'].value_counts()

# %%
label = ['Week 1', 'Week 2', 'Week 3', 'Week 4', 'Week 5', 'Week 6', 'Week 7', 'Week 8', 'Week 9', 'Week 10', 'Quit']
explode = (0, 0, 0, 0, 0, 0.1, 0.2, 0.25, 0.275, 0.45, 0.5)
plt.pie(counts, labels = label, explode=explode, colors=sb.color_palette("RdPu", 
                                     len(label)))

plt.show()

# %%
import matplotlib.pyplot as plt
import squarify    
import pandas as pd
import seaborn as sb

# Create a data frame with fake data
treemap_df = df2['ElimWeek'].value_counts(dropna=True)
label = ['Week 1', 'Week 2', 'Week 3', 'Week 4', 'Week 5', 'Week 6', 'Week 7', 'Week 8', 'Week 9', 'Week 10', 'Quit']
# plot it
squarify.plot(sizes=treemap_df, label=label, color=sb.color_palette("RdPu", 
                                     len(label)), alpha=.8 )
plt.axis('off')
plt.show()

# %%
#Word Cloud for occupations


# Create a list of word
text=(str(df2['Occupation']))

# Create the wordcloud object
wordcloud = WordCloud(width=200, height=200, max_words=50, margin=0, stopwords=['Occupation', 'dtype'], background_color="whitesmoke", colormap='PuRd_r').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
counts = df2['ElimWeek'].value_counts()
age_counts = df2['Age_groups'].value_counts()
age_counts
# Out:
# Late 20s     247
# Early 20s    117
# Early 30s     55
# Late 30s       3
# Name: Age_groups, dtype: int64

# %%
#Try and isolate the age groups and use small multiples to get four
#graphs showing the amount of eliminations per week per group.
age_means.head()
# Out:
#   Age_groups ElimWeek    Age  Season  Followers(k)  count
# 0  Early 20s      1.0  887.0     466         3.361     38
# 1  Early 20s      2.0  307.0     172        13.215     13
# 2  Early 20s      3.0  346.0     124         0.000     15
# 3  Early 20s      4.0  256.0     128         0.000     11
# 4  Early 20s      5.0  303.0     196       329.900     13
